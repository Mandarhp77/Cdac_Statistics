# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("pizza.csv")
auto = pd.read_csv("Insure_auto.csv")
iris = pd.read_csv("iris.csv")
boston = pd.read_csv("Boston.csv")

# %%
df.head()
# Out:
#    Promote   Sales  Unnamed: 2  Deviation  Squared deviation
# 0     23.0   554.0         NaN -28.526316         813.750693
# 1     56.0  1339.0         NaN   4.473684          20.013850
# 2     34.0   815.0         NaN -17.526316         307.171745
# 3     25.0   609.0         NaN -26.526316         703.645429
# 4     67.0  1600.0         NaN  15.473684         239.434903

# %%
df["Promote"].cov(df["Sales"])
# Out:
# 14654.060941828255

# %%
df["Promote"].corr(df["Sales"])
# Out:
# 0.9943916799675253

# %%
sns.scatterplot(data=df, x="Promote", y="Sales")
# Out:
# <AxesSubplot:xlabel='Promote', ylabel='Sales'>

# %%
auto.head()
# Out:
#   Branch  Home  Automobile  Operating_Cost
# 0    B01   400        1200          124000
# 1    B02   350         360           71000
# 2    B03   600         800          136000
# 3    B04   800        1800          219000
# 4    B05   900        1600          230000

# %%
auto["Home"].corr(auto["Operating_Cost"])
# Out:
# 0.9455357094743932

# %%
cor=auto.corr()
cor
# Out:
#                     Home  Automobile  Operating_Cost
# Home            1.000000    0.548839        0.945536
# Automobile      0.548839    1.000000        0.786810
# Operating_Cost  0.945536    0.786810        1.000000

# %%
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(auto,diag_kind="kde")
plt.show()

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
co=iris.corr()

# %%
sns.heatmap(co,annot=True)
# Out:
# <AxesSubplot:>

# %%
corelation = boston.corr() 
corelation
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
fig = plt.figure(figsize=(14,14))
sns.heatmap(corelation, annot = True)
# Out:
# <AxesSubplot:>
